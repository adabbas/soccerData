# %%
import pandas as pd

# %%
#token = 1234567890

# %%
import http.client
import json

connection = http.client.HTTPConnection('api.football-data.org')
headers = { 'X-Auth-Token': token, 'X-Response-Control': 'minified' }
#connection.request('GET', '/v1/soccerseasons', None, headers )
connection.request('GET', '/v1/soccerseasons/399/teams', None, headers )
response = json.loads(connection.getresponse().read().decode())

# %%
data = pd.DataFrame(response)

# %%
data.iloc[13]['teams']
# Out:
# {'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/3/3f/Real_Madrid_Logo.svg',
#  'id': 86,
#  'name': 'Real Madrid CF',
#  'shortName': 'Real Madrid',
#  'squadMarketValue': '704,800,000 €'}

# %%
connection = http.client.HTTPConnection('api.football-data.org')
headers = { 'X-Auth-Token': token, 'X-Response-Control': 'minified' }
connection.request('GET', '/v1/teams/86/players', None, headers )
response = json.loads(connection.getresponse().read().decode())

# %%
data = pd.DataFrame(response)

# %%
list_players = [x[1]['players'] for x in data.iterrows()]
pd.DataFrame(list_players)
# Out:
#    contractUntil dateOfBirth    id  jerseyNumber    marketValue  \
# 0     2021-06-30  1994-05-06  1014            16   20,000,000 €
# 1     2021-06-30  1992-02-23  2419            14   15,000,000 €
# 2     2020-06-30  1986-10-02  3137            13    7,500,000 €
# 3     2020-06-30  1991-07-01  3155            18    5,000,000 €
# 4     2020-06-30  1986-12-15  3505             1   15,000,000 €
# 5     2020-06-30  1986-03-30  3508             4   40,000,000 €
# 6     2020-06-30  1993-04-25  3509             2   30,000,000 €
# 7     2017-06-30  1983-02-26  3510             3   10,000,000 €
# 8     2020-06-30  1990-01-18  3511             6    5,000,000 €
# 9     2020-06-30  1992-01-11  3513            15   25,000,000 €
# 10    2016-06-30  1983-01-17  3514            17    3,000,000 €
# 11    2018-06-30  1985-09-09  3516            19   50,000,000 €
# 12    2020-06-30  1990-01-04  3517             8   50,000,000 €
# 13    2020-06-30  1991-07-12  3519            10   80,000,000 €
# ...
